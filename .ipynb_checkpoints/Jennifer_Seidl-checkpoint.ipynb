# %% [markdown]
# <br>
# <span style = 'font-size: 32px; font-family: Avenir Light, sans-serif'>Jennifer</span><span style = 'font-size: 32px; font-family: Avenir Medium, sans-serif'> Seidl</span>
#
# --------------------------------------------------------------------
#
# *Over ten years of multidisciplinary management and team collaboration experience. My well-rounded work history cultivated strong leadership skills and flexibility while executing sales in the office and traveling. In conjunction with my other roles, I continually served as a skilled promoter and communicator for five years. A jack of all trades, I was
# responsible for delivering complex marketing information to diverse audiences in data visualizations, print, and social media. Upon every opportunity, I seek: to serve both my team, the customer by empowering them with the agency of product knowledge and to grow sales, services, and capabilities*
#
# --------------------------------------------------------------------
#
# <span style = 'font-size: 24px; font-family: Avenir Medium, sans-serif'>Projects</span>
#
# --------------------------------------------------------------------
# <div>
# <table style='table-layout:fixed; table-width:100px'><tr>
#     <th style='text-align:left'>
# <a href="https://ph1-618o.github.io/senatorsSiteDesign/templates/index.html" target="_blank"><h3>&nbsp;&nbsp;&nbsp;&nbsp;senateSiteDesign<br></h3></a></th>
#     <th style='text-align:left'>
# <a href="https://github.com/ph1-618O/covidOverTime" target="_blank">
#     <h3>&nbsp;&nbsp;&nbsp;&nbsp;covidOverTime<br></h3></a></th>
#     <th style='text-align:left'>
# <a href="https://ph1-618o.github.io/scatterD3/" target="_blank"><h3>&nbsp;&nbsp;&nbsp;&nbsp;scatterD3<br></h3></a></th></tr>
# <tr><td style='text-align:left'>
#     <p>A full stack application with Python, HTML/CSS, <br>Javascript and SQL analyzing Senatorial&nbsp;Contributions and committee positions</p></td>
# <td style='text-align:center'>
#     <p>An interactive Python program<br>
#         that shows coronavirus cases by user-chosen state</p></td>
# <td style='text-align:center'><p>Visualizing health risks by state using interactive
# 	D3.js, JavaScript, HTML & CSS</p></td>
#     </table>
# </div>
#
# --------------------------------------------------------------------
# <span style = 'font-size: 24px; font-family: Avenir Medium, sans-serif'>Work</span><span style = 'font-size: 24px; font-family: Avenir Light, sans-serif'> Experience</span>
#
# <!-- <details>
#     <summary markdown = 'span'><em>➤ Click to see more</em></summary> -->
# | | | | |
# |:-----------------|-------------|---------------|---------------|
#     |<h3 style = 'font-family: Avenir Medium, sans-serif'>&nbsp;&nbsp;&nbsp;&nbsp;**International Language School of Sasebo**<br></h3>|||<span style = 'font-size: 12px; font-family: Avenir Medium, sans-serif'><span style = 'overflow-wrap: anywhere; display: inline'><strong>*English Language Teacher*</strong></span><br>*2018 - 2019 Sasebo, Japan* |
# |<ul><li>Designed personalized verbal and written English lessons on location and at remote sites for over forty students from individuals to large groups</li></ul>
# <ul><li>Adapted teaching methods for learners of all English levels such as beginner, intermediate, conversational, advanced, and business<br></li></ul>
#     <ul><li>Japanese Language A1 Proficiency<br><br><br></li></ul>|||
# |<h3 style = 'font-family: Avenir Medium, sans-serif'>&nbsp;&nbsp;&nbsp;&nbsp;**Navy Fleet and Family Support Center<br>**</h3>|||<span style = 'font-size: 12px; font-family: Avenir Medium, sans-serif'><span style = 'overflow-wrap: anywhere; display: inline'><strong>*Program Coordinator Volunteer*</strong></span><br> *2018 - 2019 Sasebo, Japan*|
# |<ul><li>Conceptualized and developed an unfunded resiliency program for serving the Navy community</li></ul>
# <ul><li>Responsible for social media marketing, curriculum development, and program management</li></ul>
#     <ul>-  *Presidents Volunteer Service Award*<br><br><br></ul>|||
# |<h3 style = 'font-family: Avenir Medium, sans-serif'>&nbsp;&nbsp;&nbsp;&nbsp;**Bennett’s Creek Nursery<br>**</h3>|||<span style = 'font-size: 12px; font-family: Avenir Medium, sans-serif'><span style = 'overflow-wrap: anywhere; display: inline'><strong>*Office Manager / Sales Support*</strong></span><br> *2012 - 2014 Suffolk, Virginia*|
# |<ul><li>Served as a proxy office manager, and salesperson between the Main Office, and four Distribution Centers in two states</li></ul>
# <ul><li>Initiated strategic, targeted advertising with branded products; managed newsletter, and company blog</li></ul>
# <ul><li>Oversaw brand-tune up for print and social media</li></ul>
# <ul><li>Dispatched tractor-trailer deliveries to retailers locally in Virginia and along the East Coast</li></ul>|||
# |<br><br><br> | | | |
# |<h3 style = 'font-family: Avenir Medium, sans-serif'>&nbsp;&nbsp;&nbsp;&nbsp;Starbucks Coffee Company<br><br></h3>|||<span style = 'font-size: 12px; font-family: Avenir Medium, sans-serif'><span style = 'overflow-wrap: anywhere; display: inline'><nobr><strong>*Assistant Manager&nbsp;/ Shift Supervisor*</strong></nobr></span><br>*2006 - 2012 Virginia & Florida*|
# |<ul><li>Managed all aspects: hiring, scheduling, training, loss prevention, customer service, and seasonal setups</li></ul>
# <ul><li>Coordinated a team that trained more than 50+ baristas and supervisors</li></ul>
#
# <br><br><br>
#
# <div style = 'text-align: left; font-size: 24px; font-family: Avenir Medium, sans-serif; '>Education</div>
# <div style='text-align: left'>
# <h4 style='text-align: left; font-family: Avenir Medium, sans-serif;'>Western Governors University</h4>
# <span style='font-family: Avenir Light, sans-serif;'>BS Cybersecurity and Information Assurance</span><br>
#
# <h4 style='text-align: left; font-family: Avenir Medium, sans-serif;'>George Washington University, <br>Arlington, VA</h4>
#     <span style='font-family: Avenir Light, sans-serif;'>Data Visualization Certificate</span>
#
# <h4 style='text-align: left; font-family: Avenir Medium, sans-serif;'>Tidewater Community College, <br>Chesapeake, VA</h4>
#     <span style='font-family: Avenir Light, sans-serif;'>24 Credits Horticulture</span>
#
# <h4 style='text-align: left; font-family: Avenir Medium, sans-serif;'>Pensacola State College, <br>Pensacola, FL</h4>
#     <span style='font-family: Avenir Light, sans-serif;'>21 Credits Graphic Design</span>
#
#
# <h4 style='text-align: left; font-family: Avenir Medium, sans-serif;'>George Mason University, <br>Fairfax, VA</h4>
#     <span style='font-family: Avenir Light, sans-serif;'>81 Credits Graphic Design</span>
#     <br><br><br></div>
# <span style = 'font-size: 24px; font-family: Avenir Light, sans-serif'>Skills</span>
#
# `Python` `Julia` `Ruby` `HTML/CSS` `SQL` `R` `JavaScript`
#
#
# <details>
#     <summary markdown = 'span' style = 'font-family: Avenir Medium, sans-serif'><em><h4>➤ More</h4></em></summary>
#
#     words
# </details>
#
# •[Github](github.com/ph1-618o) • [Email](j3n.s3idl@gmail.com) • [LinkedIn](https://www.linkedin.com/in/jenseidl/) •
